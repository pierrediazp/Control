# %%
import control

# %%
Gp = control.tf([1],[0.9,1])*control.tf([1],[0.21,1])
Gp
# Out:
# TransferFunction(array([1.]), array([0.189, 1.11 , 1.   ]))

# %%
control.rlocus(Gp);

# %%
Gc = 4*control.tf([1,1],[1,4])
Gc
# Out:
# TransferFunction(array([4, 4]), array([1, 4]))

# %%
(Gc*Gp).zero()
# Out:
# array([-1.])

# %%
control.rlocus(Gc*Gp);
